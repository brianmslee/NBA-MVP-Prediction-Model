# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf
import joblib

# %%
from tensorflow.keras.models import load_model
nn_model = load_model('nn_model.h5')
tuned_nn_model = load_model('tuned_nn_model.h5')
scaler = joblib.load('nn_scaler.joblib')

# %%
test_data_df = pd.read_csv('./test_data.csv')
test_data_df.head()
# Out:
#    Unnamed: 0   fga  fg3a   fta   per  ts_pct  usg_pct   bpm  \
# 0           0  24.5  13.2  11.0  30.6   0.616     40.5  11.7
# 1           1  17.3   2.8   9.5  30.9   0.644     32.3  10.8
# 2           2   8.8   0.0   6.4  24.6   0.682     17.8   7.0
# 3           3  19.2   8.0   6.4  23.7   0.588     29.3   5.5
# 4           4  21.0   9.8   7.0  23.3   0.583     29.5   5.5
#
#                   player   win_pct  ...  pts_per_g  trb_per_g  ast_per_g  \
# 0           James Harden  0.646341  ...       36.1        6.6        7.5
# 1  Giannis Antetokounmpo  0.731707  ...       27.7       12.5        5.9
# 2            Rudy Gobert  0.609756  ...       15.9       12.9        2.0
# 3         Damian Lillard  0.646341  ...       25.8        4.6        6.9
# 4            Paul George  0.597561  ...       28.0        8.2        4.1
#
#    stl_per_g  blk_per_g  fg_pct  fg3_pct  ft_pct    ws  ws_per_48
# 0        2.0        0.7   0.442    0.368   0.879  15.2      0.254
# ...

# %%
nn_X = test_data_df[['pts_per_g', 'trb_per_g', 'ast_per_g', 'stl_per_g', 'blk_per_g', 'per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
nn_X_scaled = scaler.transform(nn_X)

# %%
nn_predictions_2018 = nn_model.predict(nn_X_scaled)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
nn_predictions_2018
# Out:
# array([[ 0.5022255 ],
#        [ 0.68417555],
#        [ 0.05027356],
#        [ 0.30957136],
#        [ 0.22821051],
#        [ 0.23245868],
#        [ 0.1841925 ],
#        [ 0.04921862],
#        [ 0.01106731],
#        [ 0.10393839],
#        [ 0.17522497],
#        [ 0.10494425],
#        [ 0.29254386],
#        [ 0.00698485],
#        [-0.02677004],
#        [ 0.03433483],
#        [ 0.0433786 ],
#        [-0.01832699],
#        [ 0.14150462],
#        [-0.03053335],
#        [ 0.0736516 ],
#        [ 0.00220046],
#        [ 0.01816834],
#        [ 0.0202217 ],
#        [-0.00937809],
#        [ 0.01828338],
#        [-0.08529001],
#        [-0.03227658],
#        [-0.06776876],
#        [-0.00423494],
#        [-0.02319642],
#        [-0.00639943],
#        [-0.00496119],
#        [ 0.02084547],
#        [-0.04606291],
#        [ 0.03678871],
#        [ 0.00858848],
#        [ 0.03578904],
#        [ 0.03410644],
#        [ 0.02425182]], dtype=float32)

# %%
#2018-2019 NBA MVP Neural Network Model Predictions 
nn_mvp_pred_2018_df = test_data_df[['player']]
nn_mvp_pred_2018_df['Award Share MVP Predictions'] = nn_predictions_2018
nn_mvp_pred_2018_df.head()
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\2083778409.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn_mvp_pred_2018_df['Award Share MVP Predictions'] = nn_predictions_2018
#                   player  Award Share MVP Predictions
# 0           James Harden                     0.502226
# 1  Giannis Antetokounmpo                     0.684176
# 2            Rudy Gobert                     0.050274
# 3         Damian Lillard                     0.309571
# 4            Paul George                     0.228211

# %%
season_df_2019 = pd.DataFrame({'player': ['Giannis Antetokounmpo', 'LeBron James', 'James Harden', 'Luka Dončić', 'Kawhi Leonard', 'Anthony Davis',
                                          'Chris Paul', 'Damian Lillard', 'Nikola Jokić', 'Pascal Siakam', 'Jimmy Butler', 'Jayson Tatum'],
                                'pts_per_g': [29.5, 25.3, 34.3, 28.8, 27.1, 26.1, 17.6, 30, 19.9, 22.9, 19.9, 23.4],
                                'trb_per_g': [13.6, 7.8, 6.6, 9.4, 7.1, 9.3, 5, 4.3, 9.7, 7.3, 6.7, 7], 
                                'ast_per_g': [5.6, 10.2, 7.5, 8.8, 4.9, 3.2, 6.7, 8, 7, 3.5, 6, 3],
                                'stl_per_g': [1, 1.2, 1.8, 1, 1.8, 1.5, 1.6, 1.1, 1.2, 1, 1.8, 1.4],
                                'blk_per_g': [1, 0.5, 0.9, 0.2, 0.6, 2.3, 0.2, 0.3, 0.6, 0.9, 0.6, 0.9],
                                'per': [31.9, 25.5, 29.1, 27.6, 26.9, 27.4, 21.7, 26.9, 24.9, 17.9, 23.6, 20.4],
                                'bpm': [11.5, 8.4, 9.6, 8.4, 8.9, 8.0, 4.4, 7.5, 7.4, 1.8, 5.4, 4.0],
                                'usg_pct': [37.5, 31.5, 36.3, 36.8, 33.0, 29.3, 23.3, 30.3, 26.6, 28.1, 25.1, 28.6],
                                'win_pct': [.767, .732, .611, .573, .681, .732, .611, .473, .630, .736, .603, .667], 
                                'ws': [11.1, 9.8, 13.1, 8.8, 8.7, 11.1, 8.9, 11.6, 9.8, 5.4, 9, 6.9], 
                                'ws_per_48': [0.279, 0.204, 0.254, 0.207, 0.226, 0.25, 0.193, 0.225, 0.202, 0.123, 0.221, 0.146]})

# %%
season_df_2019.sample(frac=1)
season_df_2019.head()
# Out:
#                   player  pts_per_g  trb_per_g  ast_per_g  stl_per_g  \
# 0  Giannis Antetokounmpo       29.5       13.6        5.6        1.0
# 1           LeBron James       25.3        7.8       10.2        1.2
# 2           James Harden       34.3        6.6        7.5        1.8
# 3            Luka Dončić       28.8        9.4        8.8        1.0
# 4          Kawhi Leonard       27.1        7.1        4.9        1.8
#
#    blk_per_g   per   bpm  usg_pct  win_pct    ws  ws_per_48
# 0        1.0  31.9  11.5     37.5    0.767  11.1      0.279
# 1        0.5  25.5   8.4     31.5    0.732   9.8      0.204
# 2        0.9  29.1   9.6     36.3    0.611  13.1      0.254
# 3        0.2  27.6   8.4     36.8    0.573   8.8      0.207
# 4        0.6  26.9   8.9     33.0    0.681   8.7      0.226

# %%
X_2019 = season_df_2019[['pts_per_g', 'trb_per_g', 'ast_per_g', 'stl_per_g', 'blk_per_g', 'per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
X_2019_scaled = scaler.transform(X_2019)

# %%
nn_predictions_2019 = nn_model.predict(X_2019_scaled)
# Out:
# 1/1 [==============================] - 0s 65ms/step

# %%
#2019-2020 NBA MVP Neural Network Model Predictions 
nn_mvp_pred_2019_df = season_df_2019[['player']]
nn_mvp_pred_2019_df['nn_predictions_2019'] = nn_predictions_2019
nn_mvp_pred_2019_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\1543009445.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn_mvp_pred_2019_df['nn_predictions_2019'] = nn_predictions_2019
#                    player  nn_predictions_2019
# 0   Giannis Antetokounmpo             0.423505
# 1            LeBron James             0.245900
# 2            James Harden             0.316188
# 3             Luka Dončić            -0.107467
# 4           Kawhi Leonard             0.227271
# 5           Anthony Davis             0.361232
# 6              Chris Paul             0.035884
# 7          Damian Lillard             0.113318
# 8            Nikola Jokić             0.067092
# 9           Pascal Siakam             0.000680
# ...

# %%
season_df_2020 = pd.DataFrame({'player': ['Nikola Jokić', 'Joel Embiid', 'Stephen Curry', 'Giannis Antetokounmpo', 'Chris Paul', 'Luka Dončić', 'Damian Lillard', 
                                          'Julius Randle', 'Derrick Rose', 'Rudy Gobert', 'Russell Westbrook', 'Ben Simmons', 'James Harden', 'LeBron James', 
                                          'Kawhi Leonard'],
                                'pts_per_g': [26.4, 28.5, 32, 28.1, 16.4, 27.7, 28.8, 24.1, 14.7, 14.3, 22.2, 14.3, 24.6, 25, 24.8],
                                'trb_per_g': [10.8, 10.6, 5.5, 11, 4.5, 8, 4.2, 10.2, 2.6, 13.5, 11.5, 7.2, 7.9, 7.7, 6.5], 
                                'ast_per_g': [8.3, 2.8, 5.8, 5.9, 8.9, 8.6, 7.5, 6, 4.2, 1.3, 11.7, 6.9, 10.8, 7.8, 5.2],
                                'stl_per_g': [1.3, 1, 1.2, 1.2, 1.4, 1, 0.9, 0.9, 1, 0.6, 1.4, 1.6, 1.2, 1.1, 1.6],
                                'blk_per_g': [0.7, 1.4, 0.1, 1.2, 0.3, 0.5, 0.3, 0.3, 0.4, 2.7, 0.4, 0.6, 0.8, 0.6, 0.4],
                                'per': [31.3, 30.3, 26.3, 29.2, 21.4, 25.3, 25.6, 19.7, 18.3, 23.5, 19.5, 18.3, 24.5, 24.2, 26.0],
                                'bpm': [12.1, 7.5, 8.7, 9.0, 4.6, 6.8, 6.3, 3.8, 1.9, 4.9, 3.7, 2.9, 7.2, 8.1, 7.3],
                                'usg_pct': [29.6, 35.3, 34.8, 32.5, 22.6, 36.0, 31.4, 29.3, 25.8, 17.0, 30.2, 20.2, 28.4, 31.9, 28.6],
                                'win_pct': [.653, .681, .542, .639, .708, .583, .583, .569, .569, .722, .472, .681, .667, .583, .653], 
                                'ws': [15.6, 8.8, 9, 10.2, 9.2, 7.7, 10.4, 7.8, 3.1, 11.3, 3.7, 6, 7, 5.6, 8.8], 
                                'ws_per_48': [0.301, 0.266, 0.201, 0.244, 0.201, 0.163, 0.209, 0.14, 0.118, 0.248, 0.075, 0.153, 0.208, 0.179, 0.23]})

# %%
season_df_2021 = pd.DataFrame({'player': ['Nikola Jokić', 'Joel Embiid', 'Giannis Antetokounmpo', 'Devin Booker', 'Luka Dončić', 'Jayson Tatum', 'Ja Morant', 
                                          'Stephen Curry', 'Chris Paul', 'DeMar DeRozan', 'Kevin Durant', 'LeBron James'],
                                'pts_per_g': [27.1, 30.6, 29.9, 26.8, 28.4, 26.9, 27.4, 25.5, 14.7, 27.9, 29.9, 30.3],
                                'trb_per_g': [13.8, 11.7, 11.6, 5, 9.1, 8, 5.7, 5.2, 4.4, 5.2, 7.4, 8.2], 
                                'ast_per_g': [7.9, 4.2, 5.8, 4.8, 8.7, 4.4, 6.7, 6.3, 10.8, 4.9, 6.4, 6.2],
                                'stl_per_g': [1.5, 1.1, 1.1, 1.1, 1.2, 1, 1.2, 1.3, 1.9, 0.9, 0.9, 1.3],
                                'blk_per_g': [0.9, 1.5, 1.4, 0.4, 0.6, 0.6, 0.4, 0.4, 0.3, 0.3, 0.9, 1.1],
                                'per': [32.8, 31.2, 32.1, 21.3, 25.1, 21.8, 24.4, 21.4, 20.8, 23.1, 25.6, 26.2],
                                'bpm': [13.7, 9.2, 11.2, 4.1, 8.2, 5.0, 6.1, 5.8, 5.4, 2.5, 7.2, 7.7],
                                'usg_pct': [31.9, 37.2, 34.9, 32.0, 37.4, 32.1, 33.7, 30.8, 19.7, 31.8, 31.2, 32.3], 
                                'win_pct': [.585, .622, .622, .780, .634, .622, .683, .646, .780, .561, .537, .402], 
                                'ws': [15.2, 12, 12.9, 7.6, 7.6, 9.6, 6.7, 8, 9.4, 8.8, 8.4, 7.5], 
                                'ws_per_48': [0.296, 0.252, 0.281, 0.156, 0.159, 0.169, 0.171, 0.173, 0.21, 0.154, 0.198, 0.172]})

# %%
season_df_2022 = pd.DataFrame({'player': ['Joel Embiid', 'Nikola Jokić', 'Giannis Antetokounmpo', 'Jayson Tatum', 'Shai Gilgeous-Alexander', 'Donovan Mitchell',
                                          'Domantas Sabonis', 'Luka Dončić', 'Stephen Curry', 'Jimmy Butler', 'DeAaron Fox', 'Jalen Brunson', 'Ja Morant'],
                                'pts_per_g': [33.1, 24.5, 31.1, 30.1, 31.4, 28.3, 19.1, 32.4, 29.4, 22.9, 25, 24, 26.2],
                                'trb_per_g': [10.2, 11.8, 11.8, 8.8, 4.8, 4.3, 12.3, 8.6, 6.1, 5.9, 4.2, 3.5, 5.9], 
                                'ast_per_g': [4.2, 9.8, 5.7, 4.6, 5.5, 4.4, 7.3, 8, 6.3, 5.3, 6.1, 6.2, 8.1],
                                'stl_per_g': [1, 1.3, 0.8, 1.1, 1.6, 1.5, 0.8, 1.4, 0.9, 1.8, 1.1, 0.9, 1.1],
                                'blk_per_g': [1.7, 0.7, 0.8, 0.7, 1, 0.4, 0.5, 0.5, 0.4, 0.3, 0.3, 0.2, 0.3],
                                'per': [31.4, 31.5, 29.0, 23.7, 27.2, 22.9, 23.5, 28.7, 24.1, 27.6, 21.8, 21.2, 23.3],
                                'bpm': [9.2, 13.0, 8.5, 5.5, 7.3, 6.3, 5.8, 8.9, 7.5, 8.7, 2.5, 3.9, 5.7],
                                'usg_pct': [37.0, 27.2, 38.8, 32.7, 32.8, 32.1, 21.3, 37.6, 31.0, 25.6, 30.1, 27.2, 34.9],  
                                'win_pct': [.659, .646, .707, .695, .488, .622, .585, .463, .537, .537, .585, .573, .622], 
                                'ws': [12.3, 14.9, 8.6, 10.5, 11.4, 8.9, 12.6, 10.2, 7.8, 12.3, 7.4, 8.7, 6],
                                'ws_per_48': [0.259, 0.308, 0.204, 0.185, 0.226, 0.176, 0.221, 0.204, 0.192, 0.277, 0.146, 0.175, 0.148]})

# %%
#2020-2021 NBA MVP Neural Network Model Predictions 
season_df_2020.sample(frac=1)
X_2020 = season_df_2020[['pts_per_g', 'trb_per_g', 'ast_per_g', 'stl_per_g', 'blk_per_g', 'per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
X_2020_scaled = scaler.transform(X_2020)
nn_predictions_2020 = nn_model.predict(X_2020_scaled)
nn_mvp_pred_2020_df = season_df_2020[['player']]
nn_mvp_pred_2020_df['nn_predictions_2020'] = nn_predictions_2020
nn_mvp_pred_2020_df
# Out:
# 1/1 [==============================] - 0s 61ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\982670751.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn_mvp_pred_2020_df['nn_predictions_2020'] = nn_predictions_2020
#                    player  nn_predictions_2020
# 0            Nikola Jokić             0.627566
# 1             Joel Embiid             0.358894
# 2           Stephen Curry             0.037146
# 3   Giannis Antetokounmpo             0.107723
# 4              Chris Paul             0.108736
# 5             Luka Dončić            -0.010763
# 6          Damian Lillard             0.096319
# 7           Julius Randle             0.043445
# 8            Derrick Rose             0.056647
# ...

# %%
#2021-2022 NBA MVP Neural Network Model Predictions 
season_df_2021.sample(frac=1)
X_2021 = season_df_2021[['pts_per_g', 'trb_per_g', 'ast_per_g', 'stl_per_g', 'blk_per_g', 'per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
X_2021_scaled = scaler.transform(X_2021)
nn_predictions_2021 = nn_model.predict(X_2021_scaled)
nn_mvp_pred_2021_df = season_df_2021[['player']]
nn_mvp_pred_2021_df['nn_predictions_2021'] = nn_predictions_2021
nn_mvp_pred_2021_df
# Out:
# 1/1 [==============================] - 0s 68ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\953535881.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn_mvp_pred_2021_df['nn_predictions_2021'] = nn_predictions_2021
#                    player  nn_predictions_2021
# 0            Nikola Jokić             0.513350
# 1             Joel Embiid             0.417471
# 2   Giannis Antetokounmpo             0.250968
# 3            Devin Booker             0.131169
# 4             Luka Dončić             0.001252
# 5            Jayson Tatum             0.082702
# 6               Ja Morant             0.006007
# 7           Stephen Curry            -0.022756
# 8              Chris Paul             0.205328
# ...

# %%
#2022-2023 NBA MVP Neural Network Model Predictions 
season_df_2022 = season_df_2022.sample(frac=1)
X_2022 = season_df_2022[['pts_per_g', 'trb_per_g', 'ast_per_g', 'stl_per_g', 'blk_per_g', 'per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
X_2022_scaled = scaler.transform(X_2022)
nn_predictions_2022 = nn_model.predict(X_2022_scaled)
nn_mvp_pred_2022_df = season_df_2022[['player']]
nn_mvp_pred_2022_df['nn_mvp_predictions_2022'] = nn_predictions_2022
nn_mvp_pred_2022_df
# Out:
# 1/1 [==============================] - 0s 76ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\1005050315.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn_mvp_pred_2022_df['nn_mvp_predictions_2022'] = nn_predictions_2022
#                      player  nn_mvp_predictions_2022
# 1              Nikola Jokić                 0.528517
# 0               Joel Embiid                 0.435679
# 10              DeAaron Fox                 0.000631
# 9              Jimmy Butler                 0.132145
# 12                Ja Morant                -0.008734
# 5          Donovan Mitchell                 0.132633
# 6          Domantas Sabonis                 0.083051
# 3              Jayson Tatum                 0.241013
# ...

# %%
#Hyperparameter tuned NN model 2018-2019 MVP Predictions 
tuned_nn_predictions_2018 = tuned_nn_model.predict(nn_X_scaled)
tuned_nn_mvp_pred_2018_df = test_data_df[['player']]
tuned_nn_mvp_pred_2018_df['Award Share MVP Predictions'] = tuned_nn_predictions_2018
tuned_nn_mvp_pred_2018_df.head()
# Out:
# 2/2 [==============================] - 0s 7ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\3185762541.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuned_nn_mvp_pred_2018_df['Award Share MVP Predictions'] = tuned_nn_predictions_2018
#                   player  Award Share MVP Predictions
# 0           James Harden                     0.859761
# 1  Giannis Antetokounmpo                     0.559180
# 2            Rudy Gobert                     0.051608
# 3         Damian Lillard                     0.106273
# 4            Paul George                     0.076604

# %%
#Hyperparameter tuned NN model 2019-2020 MVP Predictions 
tuned_nn_predictions_2019 = tuned_nn_model.predict(X_2019_scaled)
tuned_nn_mvp_pred_2019_df = season_df_2019[['player']]
tuned_nn_mvp_pred_2019_df['nn_predictions_2019'] = tuned_nn_predictions_2019
tuned_nn_mvp_pred_2019_df
# Out:
# 1/1 [==============================] - 0s 49ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\2134837161.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuned_nn_mvp_pred_2019_df['nn_predictions_2019'] = tuned_nn_predictions_2019
#                    player  nn_predictions_2019
# 0   Giannis Antetokounmpo             0.759768
# 1            LeBron James             0.542615
# 2            James Harden             0.591979
# 3             Luka Dončić             0.183300
# 4           Kawhi Leonard             0.226161
# 5           Anthony Davis             0.271823
# 6              Chris Paul            -0.030913
# 7          Damian Lillard             0.081913
# 8            Nikola Jokić             0.036820
# ...

# %%
#Hyperparameter tuned NN model 2020-2021 MVP Predictions 
tuned_nn_predictions_2020 = tuned_nn_model.predict(X_2020_scaled)
tuned_nn_mvp_pred_2020_df = season_df_2020[['player']]
tuned_nn_mvp_pred_2020_df['nn_predictions_2020'] = tuned_nn_predictions_2020
tuned_nn_mvp_pred_2020_df
# Out:
# 1/1 [==============================] - 0s 51ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\4120099332.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuned_nn_mvp_pred_2020_df['nn_predictions_2020'] = tuned_nn_predictions_2020
#                    player  nn_predictions_2020
# 0            Nikola Jokić             0.536799
# 1             Joel Embiid             0.407095
# 2           Stephen Curry             0.196623
# 3   Giannis Antetokounmpo             0.360891
# 4              Chris Paul            -0.007083
# 5             Luka Dončić             0.223017
# 6          Damian Lillard             0.120932
# 7           Julius Randle            -0.019216
# 8            Derrick Rose             0.004193
# ...

# %%
#Hyperparameter tuned NN model 2021-2022 MVP Predictions 
tuned_nn_predictions_2021 = tuned_nn_model.predict(X_2021_scaled)
tuned_nn_mvp_pred_2021_df = season_df_2021[['player']]
tuned_nn_mvp_pred_2021_df['nn_predictions_2021'] = tuned_nn_predictions_2021
tuned_nn_mvp_pred_2021_df
# Out:
# 1/1 [==============================] - 0s 71ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\4017635638.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuned_nn_mvp_pred_2021_df['nn_predictions_2021'] = tuned_nn_predictions_2021
#                    player  nn_predictions_2021
# 0            Nikola Jokić             0.496265
# 1             Joel Embiid             0.511801
# 2   Giannis Antetokounmpo             0.534871
# 3            Devin Booker             0.305108
# 4             Luka Dončić             0.350272
# 5            Jayson Tatum             0.110201
# 6               Ja Morant             0.296813
# 7           Stephen Curry             0.136202
# 8              Chris Paul             0.206770
# ...

# %%
#Hyperparameter tuned NN model 2022-2023 MVP Predictions 
tuned_nn_predictions_2022 = tuned_nn_model.predict(X_2022_scaled)
tuned_nn_mvp_pred_2022_df = season_df_2022[['player']]
tuned_nn_mvp_pred_2022_df['nn_predictions_2022'] = tuned_nn_predictions_2022
tuned_nn_mvp_pred_2022_df
# Out:
# 1/1 [==============================] - 0s 146ms/step
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\542644348.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuned_nn_mvp_pred_2022_df['nn_predictions_2022'] = tuned_nn_predictions_2022
#                      player  nn_predictions_2022
# 1              Nikola Jokić             0.510469
# 0               Joel Embiid             0.621408
# 10              DeAaron Fox            -0.052702
# 9              Jimmy Butler             0.084607
# 12                Ja Morant             0.238226
# 5          Donovan Mitchell             0.081783
# 6          Domantas Sabonis             0.015645
# 3              Jayson Tatum             0.195643
# ...

# %%
#Linear Regression Model Predictions for 2018-2019 MVP 
lr_scaler = joblib.load('lr_scaler.joblib')
lr_model = joblib.load('lr_model.joblib')
lr_X_2018 = test_data_df[['ws', 'ws_per_48','per', 'bpm', 'pts_per_g', 'win_pct', 'usg_pct']]
lr_X_scaled = lr_scaler.transform(lr_X_2018)
lr_pred_2018 = lr_model.predict(lr_X_scaled)
lr_mvp_pred_2018_df = test_data_df[['player']]
lr_mvp_pred_2018_df['lr_predictions_2018'] = lr_pred_2018
lr_mvp_pred_2018_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\3362434220.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lr_mvp_pred_2018_df['lr_predictions_2018'] = lr_pred_2018
#                    player  lr_predictions_2018
# 0            James Harden             0.587254
# 1   Giannis Antetokounmpo             0.484347
# 2             Rudy Gobert             0.161406
# 3          Damian Lillard             0.248280
# 4             Paul George             0.219494
# 5            Nikola Jokic             0.306914
# 6            Kevin Durant             0.244155
# 7            Clint Capela             0.034611
# 8      Karl-Anthony Towns             0.121286
# 9          Nikola Vucevic             0.129864
# ...

# %%
#Linear Regression Model Predictions for 2019-2020 MVP 
season_df_2019 = season_df_2019.sample(frac=1)
lr_X_2019 = season_df_2019[['ws', 'ws_per_48','per', 'bpm', 'pts_per_g', 'win_pct', 'usg_pct']]
lr_X_scaled_2019 = lr_scaler.transform(lr_X_2019)
lr_pred_2019 = lr_model.predict(lr_X_scaled_2019)
lr_mvp_pred_2019_df = season_df_2019[['player']]
lr_mvp_pred_2019_df['lr_predictions_2019'] = lr_pred_2019
lr_mvp_pred_2019_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\2127025835.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lr_mvp_pred_2019_df['lr_predictions_2019'] = lr_pred_2019
#                    player  lr_predictions_2019
# 11           Jayson Tatum             0.098479
# 8            Nikola Jokić             0.192489
# 3             Luka Dončić             0.254343
# 10           Jimmy Butler             0.059461
# 7          Damian Lillard             0.194341
# 4           Kawhi Leonard             0.277095
# 0   Giannis Antetokounmpo             0.484728
# 6              Chris Paul             0.036329
# 5           Anthony Davis             0.317535
# 9           Pascal Siakam             0.047719
# ...

# %%
#Linear Regression Model Predictions for 2020-2021 MVP 
season_df_2020 = season_df_2020.sample(frac=1)
lr_X_2020 = season_df_2020[['ws', 'ws_per_48','per', 'bpm', 'pts_per_g', 'win_pct', 'usg_pct']]
lr_X_scaled_2020 = lr_scaler.transform(lr_X_2020)
lr_pred_2020 = lr_model.predict(lr_X_scaled_2020)
lr_mvp_pred_2020_df = season_df_2020[['player']]
lr_mvp_pred_2020_df['lr_predictions_2020'] = lr_pred_2020
lr_mvp_pred_2020_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\3220154798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lr_mvp_pred_2020_df['lr_predictions_2020'] = lr_pred_2020
#                    player  lr_predictions_2020
# 0            Nikola Jokić             0.471003
# 4              Chris Paul             0.092653
# 8            Derrick Rose            -0.162738
# 6          Damian Lillard             0.211766
# 9             Rudy Gobert             0.101603
# 11            Ben Simmons            -0.052233
# 1             Joel Embiid             0.255245
# 13           LeBron James             0.116410
# 14          Kawhi Leonard             0.181236
# 12           James Harden             0.143395
# ...

# %%
#Linear Regression Model Predictions for 2021-2022 MVP 
season_df_2021 = season_df_2021.sample(frac=1)
lr_X_2021 = season_df_2021[['ws', 'ws_per_48','per', 'bpm', 'pts_per_g', 'win_pct', 'usg_pct']]
lr_X_scaled_2021 = lr_scaler.transform(lr_X_2021)
lr_pred_2021 = lr_model.predict(lr_X_scaled_2021)
lr_mvp_pred_2021_df = season_df_2021[['player']]
lr_mvp_pred_2021_df['lr_predictions_2021'] = lr_pred_2021
lr_mvp_pred_2021_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\1472048027.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lr_mvp_pred_2021_df['lr_predictions_2021'] = lr_pred_2021
#                    player  lr_predictions_2021
# 1             Joel Embiid             0.394418
# 11           LeBron James             0.099658
# 9           DeMar DeRozan             0.106888
# 6               Ja Morant             0.204099
# 7           Stephen Curry             0.151277
# 4             Luka Dončić             0.288574
# 5            Jayson Tatum             0.187395
# 3            Devin Booker             0.224471
# 10           Kevin Durant             0.158377
# 8              Chris Paul             0.125115
# ...

# %%
#Linear Regression Model Predictions for 2022-2023 MVP 
season_df_2022 = season_df_2022.sample(frac=1)
lr_X_2022 = season_df_2022[['ws', 'ws_per_48','per', 'bpm', 'pts_per_g', 'win_pct', 'usg_pct']]
lr_X_scaled_2022 = lr_scaler.transform(lr_X_2022)
lr_pred_2022 = lr_model.predict(lr_X_scaled_2022)
lr_mvp_pred_2022_df = season_df_2022[['player']]
lr_mvp_pred_2022_df['lr_predictions_2022'] = lr_pred_2022
lr_mvp_pred_2022_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\305475981.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lr_mvp_pred_2022_df['lr_predictions_2022'] = lr_pred_2022
#                      player  lr_predictions_2022
# 6          Domantas Sabonis             0.141926
# 8             Stephen Curry             0.133411
# 4   Shai Gilgeous-Alexander             0.213455
# 12                Ja Morant             0.150894
# 0               Joel Embiid             0.430560
# 9              Jimmy Butler             0.174842
# 10              DeAaron Fox             0.056389
# 3              Jayson Tatum             0.292007
# 2     Giannis Antetokounmpo             0.380045
# 11            Jalen Brunson             0.054711
# ...

# %%
#Random Forest Regression Model Predictions for 2018-2019 MVP 
rf_scaler = joblib.load('rf_scaler.joblib')
rf_model = joblib.load('rf_model.joblib')
rf_X = test_data_df[['per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
rf_X_scaled = rf_scaler.transform(rf_X)
rf_pred_2018 = rf_model.predict(rf_X_scaled)
rf_pred_2018_df = test_data_df[['player']]
rf_pred_2018_df['rf_model_mvp_pred_2018'] = rf_pred_2018
rf_pred_2018_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\3291800680.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rf_pred_2018_df['rf_model_mvp_pred_2018'] = rf_pred_2018
#                    player  rf_model_mvp_pred_2018
# 0            James Harden                0.618860
# 1   Giannis Antetokounmpo                0.736708
# 2             Rudy Gobert                0.148884
# 3          Damian Lillard                0.122914
# 4             Paul George                0.132554
# 5            Nikola Jokic                0.223894
# 6            Kevin Durant                0.134150
# 7            Clint Capela                0.150860
# 8      Karl-Anthony Towns                0.088748
# 9          Nikola Vucevic                0.097992
# ...

# %%
#Random Forest Regression Model Predictions for 2019-2020 MVP 
rf_X_2019 = season_df_2019[['per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
rf_X_2019_scaled = rf_scaler.transform(rf_X_2019)
rf_pred_2019 = rf_model.predict(rf_X_2019_scaled)
rf_pred_2019_df = season_df_2019[['player']]
rf_pred_2019_df['rf_pred_2019'] = rf_pred_2019
rf_pred_2019_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\848198057.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rf_pred_2019_df['rf_pred_2019'] = rf_pred_2019
#                    player  rf_pred_2019
# 11           Jayson Tatum      0.013472
# 8            Nikola Jokić      0.116530
# 3             Luka Dončić      0.237146
# 10           Jimmy Butler      0.069484
# 7          Damian Lillard      0.120714
# 4           Kawhi Leonard      0.158582
# 0   Giannis Antetokounmpo      0.475808
# 6              Chris Paul      0.089132
# 5           Anthony Davis      0.285192
# 9           Pascal Siakam      0.013300
# 2            James Harden      0.495756
# 1            LeBron James      0.361732

# %%
#Random Forest Regression Model Predictions for 2020-2021 MVP 
rf_X_2020 = season_df_2020[['per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
rf_X_2020_scaled = rf_scaler.transform(rf_X_2020)
rf_pred_2020 = rf_model.predict(rf_X_2020_scaled)
rf_pred_2020_df = season_df_2020[['player']]
rf_pred_2020_df['rf_pred_2020'] = rf_pred_2020
rf_pred_2020_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\2060399107.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rf_pred_2020_df['rf_pred_2020'] = rf_pred_2020
#                    player  rf_pred_2020
# 0            Nikola Jokić      0.633824
# 4              Chris Paul      0.028200
# 8            Derrick Rose      0.014768
# 6          Damian Lillard      0.150614
# 9             Rudy Gobert      0.240818
# 11            Ben Simmons      0.003990
# 1             Joel Embiid      0.187068
# 13           LeBron James      0.094020
# 14          Kawhi Leonard      0.104224
# 12           James Harden      0.146386
# 3   Giannis Antetokounmpo      0.229322
# 7           Julius Randle      0.017806
# ...

# %%
#Random Forest Regression Model Predictions for 2021-2022 MVP 
rf_X_2021 = season_df_2021[['per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
rf_X_2021_scaled = rf_scaler.transform(rf_X_2021)
rf_pred_2021 = rf_model.predict(rf_X_2021_scaled)
rf_pred_2021_df = season_df_2021[['player']]
rf_pred_2021_df['rf_pred_2021'] = rf_pred_2021
rf_pred_2021_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\1545474270.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rf_pred_2021_df['rf_pred_2021'] = rf_pred_2021
#                    player  rf_pred_2021
# 1             Joel Embiid      0.455040
# 11           LeBron James      0.079722
# 9           DeMar DeRozan      0.024904
# 6               Ja Morant      0.144596
# 7           Stephen Curry      0.036114
# 4             Luka Dončić      0.328046
# 5            Jayson Tatum      0.129428
# 3            Devin Booker      0.160996
# 10           Kevin Durant      0.104822
# 8              Chris Paul      0.059010
# 2   Giannis Antetokounmpo      0.399006
# 0            Nikola Jokić      0.605500

# %%
#Random Forest Regression Model Predictions for 2022-2023 MVP 
rf_X_2022 = season_df_2022[['per', 'bpm', 'usg_pct', 'win_pct', 'ws', 'ws_per_48']]
rf_X_2022_scaled = rf_scaler.transform(rf_X_2022)
rf_pred_2022 = rf_model.predict(rf_X_2022_scaled)
rf_pred_2022_df = season_df_2022[['player']]
rf_pred_2022_df['rf_pred_2022'] = rf_pred_2022
rf_pred_2022_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_44528\799758863.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rf_pred_2022_df['rf_pred_2022'] = rf_pred_2022
#                      player  rf_pred_2022
# 6          Domantas Sabonis      0.072284
# 8             Stephen Curry      0.063614
# 4   Shai Gilgeous-Alexander      0.113566
# 12                Ja Morant      0.163448
# 0               Joel Embiid      0.482250
# 9              Jimmy Butler      0.185054
# 10              DeAaron Fox      0.018704
# 3              Jayson Tatum      0.210900
# 2     Giannis Antetokounmpo      0.347822
# 11            Jalen Brunson      0.021094
# 1              Nikola Jokić      0.554258
# 5          Donovan Mitchell      0.121940
# ...
